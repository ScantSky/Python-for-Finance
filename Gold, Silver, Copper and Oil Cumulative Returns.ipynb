# %%
pip install --upgrade yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\kunal\anaconda3\lib\site-packages (1.0)Note: you may need to restart the kernel to use updated packages.
#
# Collecting yfinance
#   Downloading yfinance-1.1.0-py2.py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\kunal\anaconda3\lib\site-packages (from yfinance) (3.0.0)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\kunal\anaconda3\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\kunal\anaconda3\lib\site-packages (from yfinance) (2.32.2)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\kunal\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\kunal\anaconda3\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\kunal\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\kunal\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\kunal\anaconda3\lib\site-packages (from yfinance) (3.17.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\kunal\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: curl_cffi<0.14,>=0.7 in c:\users\kunal\anaconda3\lib\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\kunal\anaconda3\lib\site-packages (from yfinance) (3.20.3)
# Requirement already satisfied: websockets>=13.0 in c:\users\kunal\anaconda3\lib\site-packages (from yfinance) (16.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\kunal\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\kunal\anaconda3\lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (1.16.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\kunal\anaconda3\lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kunal\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\kunal\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kunal\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kunal\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kunal\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.2.2)
# Requirement already satisfied: pycparser in c:\users\kunal\anaconda3\lib\site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\kunal\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)
# Downloading yfinance-1.1.0-py2.py3-none-any.whl (129 kB)
#    ---------------------------------------- 0.0/129.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/129.9 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/129.9 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/129.9 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/129.9 kB ? eta -:--:--
#    --------- ----------------------------- 30.7/129.9 kB 186.2 kB/s eta 0:00:01
#    ------------------ -------------------- 61.4/129.9 kB 272.3 kB/s eta 0:00:01
#    -------------------------------- ----- 112.6/129.9 kB 435.7 kB/s eta 0:00:01
#    -------------------------------------- 129.9/129.9 kB 450.0 kB/s eta 0:00:00
# Installing collected packages: yfinance
#   Attempting uninstall: yfinance
#     Found existing installation: yfinance 1.0
#     Uninstalling yfinance-1.0:
#       Successfully uninstalled yfinance-1.0
# Successfully installed yfinance-1.1.0

# %%
pip install --upgrade numexpr bottleneck
# Out:
# Requirement already satisfied: numexpr in c:\users\kunal\anaconda3\lib\site-packages (2.8.7)
# Collecting numexpr
#   Downloading numexpr-2.14.1-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Requirement already satisfied: bottleneck in c:\users\kunal\anaconda3\lib\site-packages (1.3.7)
# Collecting bottleneck
#   Downloading bottleneck-1.6.0-cp312-cp312-win_amd64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\kunal\anaconda3\lib\site-packages (from numexpr) (1.26.4)
# Downloading numexpr-2.14.1-cp312-cp312-win_amd64.whl (160 kB)
#    ---------------------------------------- 0.0/160.2 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/160.2 kB ? eta -:--:--
#    ---- ---------------------------------- 20.5/160.2 kB 217.9 kB/s eta 0:00:01
#    --------- ----------------------------- 41.0/160.2 kB 326.8 kB/s eta 0:00:01
#    ------------------------ ------------- 102.4/160.2 kB 653.6 kB/s eta 0:00:01
#    ------------------------------------ - 153.6/160.2 kB 833.5 kB/s eta 0:00:01
#    -------------------------------------- 160.2/160.2 kB 738.7 kB/s eta 0:00:00
# Downloading bottleneck-1.6.0-cp312-cp312-win_amd64.whl (113 kB)
#    ---------------------------------------- 0.0/113.5 kB ? eta -:--:--
#    ---------------------------------------- 113.5/113.5 kB 6.9 MB/s eta 0:00:00
# Installing collected packages: numexpr, bottleneck
#   Attempting uninstall: numexpr
#     Found existing installation: numexpr 2.8.7
#     Uninstalling numexpr-2.8.7:
#       Successfully uninstalled numexpr-2.8.7
#   Attempting uninstall: bottleneck
#     Found existing installation: Bottleneck 1.3.7
#     Uninstalling Bottleneck-1.3.7:
#       Successfully uninstalled Bottleneck-1.3.7
# Successfully installed bottleneck-1.6.0 numexpr-2.14.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import plotly.offline as pyo
import yfinance as yf
import numpy as np
pyo.init_notebook_mode(connected=True)
pd.options.plotting.backend = 'plotly'
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
stocklist = ['GC=F', 'SI=F', 'HG=F', 'CL=F']
stocklist
# Out:
# ['GC=F', 'SI=F', 'HG=F', 'CL=F']

# %%
df = yf.download(stocklist, start='2015-01-01', end='2025-12-31')
df
# Out:
# [*********************100%***********************]  4 of 4 completed
# Price           Close                                       High               \
# Ticker           CL=F         GC=F    HG=F       SI=F       CL=F         GC=F
# Date
# 2015-01-02  52.689999  1186.000000  2.8385  15.734000  55.110001  1194.500000
# 2015-01-05  50.040001  1203.900024  2.7930  16.179001  52.730000  1206.900024
# 2015-01-06  47.930000  1219.300049  2.8040  16.603001  50.369999  1220.000000
# 2015-01-07  48.650002  1210.599976  2.7960  16.510000  49.310001  1219.199951
# 2015-01-08  48.790001  1208.400024  2.8070  16.351000  49.650002  1215.699951
# ...               ...          ...     ...        ...        ...          ...
# 2025-12-23  58.380001  4482.799805  5.4760  70.485001  58.560001  4503.799805
# 2025-12-24  58.349998  4480.600098  5.4985  71.030998  58.750000  4503.399902
# 2025-12-26  56.740002  4529.100098  5.7665  76.486000  58.880001  4556.299805
# 2025-12-29  58.080002  4325.100098  5.4905  69.856003  58.299999  4379.000000
# 2025-12-30  57.950001  4370.100098  5.7275  77.374001  58.470001  4403.600098
#
# Price                                Low                                  \
# Ticker        HG=F       SI=F       CL=F         GC=F    HG=F       SI=F
# Date
# 2015-01-02  2.8420  15.815000  52.029999  1169.500000  2.8365  15.535000
# 2015-01-05  2.8295  16.179001  49.680000  1180.099976  2.7880  16.179001
# 2015-01-06  2.8060  16.603001  47.549999  1203.500000  2.7915  16.603001
# 2015-01-07  2.8090  16.549999  46.830002  1210.599976  2.7910  16.480000
# 2015-01-08  2.8175  16.351000  47.730000  1206.300049  2.7865  16.351000
# ...            ...        ...        ...          ...     ...        ...
# 2025-12-23  5.5245  70.574997  57.740002  4450.399902  5.4230  69.074997
# 2025-12-24  5.5640  71.514999  58.130001  4468.399902  5.4700  71.000000
# 2025-12-26  5.7800  78.839996  56.650002  4502.000000  5.6095  73.735001
# 2025-12-29  5.7885  79.699997  56.910000  4325.100098  5.4905  69.856003
# 2025-12-30  5.7355  77.410004  57.599998  4338.000000  5.4975  70.500000
#
# Price            Open                                    Volume          \
# Ticker           CL=F         GC=F    HG=F       SI=F      CL=F    GC=F
# Date
# 2015-01-02  53.759998  1184.000000  2.8420  15.790000  268708.0   138.0
# 2015-01-05  52.610001  1180.300049  2.8295  16.179001  375782.0   470.0
# 2015-01-06  50.000000  1203.500000  2.7950  16.603001  451642.0    97.0
# 2015-01-07  48.000000  1219.199951  2.7920  16.480000  460083.0    29.0
# 2015-01-08  48.779999  1207.000000  2.7960  16.351000  362081.0    92.0
# ...               ...          ...     ...        ...       ...     ...
# 2025-12-23  57.950001  4503.299805  5.4360  69.080002  183633.0   694.0
# 2025-12-24  58.470001  4500.700195  5.5000  71.514999  111762.0   500.0
# 2025-12-26  58.349998  4512.000000  5.6095  74.500000  166669.0   263.0
# 2025-12-29  57.040001  4371.500000  5.7885  79.699997  178590.0  2044.0
# 2025-12-30  57.810001  4346.399902  5.5120  71.330002  143802.0  1837.0
#
# Price
# Ticker        HG=F    SI=F
# Date
# 2015-01-02   220.0    13.0
# 2015-01-05   326.0     0.0
# 2015-01-06   312.0     2.0
# 2015-01-07   463.0     9.0
# 2015-01-08   242.0     0.0
# ...            ...     ...
# 2025-12-23   724.0    40.0
# 2025-12-24  1111.0    35.0
# 2025-12-26   876.0   140.0
# 2025-12-29  2538.0  1608.0
# 2025-12-30  3056.0   992.0
#
# [2766 rows x 20 columns]

# %%
df.Close
# Out:
# Ticker           CL=F         GC=F    HG=F       SI=F
# Date
# 2015-01-02  52.689999  1186.000000  2.8385  15.734000
# 2015-01-05  50.040001  1203.900024  2.7930  16.179001
# 2015-01-06  47.930000  1219.300049  2.8040  16.603001
# 2015-01-07  48.650002  1210.599976  2.7960  16.510000
# 2015-01-08  48.790001  1208.400024  2.8070  16.351000
# ...               ...          ...     ...        ...
# 2025-12-23  58.380001  4482.799805  5.4760  70.485001
# 2025-12-24  58.349998  4480.600098  5.4985  71.030998
# 2025-12-26  56.740002  4529.100098  5.7665  76.486000
# 2025-12-29  58.080002  4325.100098  5.4905  69.856003
# 2025-12-30  57.950001  4370.100098  5.7275  77.374001
#
# [2766 rows x 4 columns]

# %%
log_returns = np.log(df.Close / df.Close.shift(1)).dropna()
log_returns*100
# Out:
# C:\Users\KUNAL\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:347: RuntimeWarning:
#
# invalid value encountered in log
# Ticker          CL=F      GC=F      HG=F       SI=F
# Date
# 2015-01-05 -5.160295  1.498001 -1.615947   2.789017
# 2015-01-06 -4.308108  1.271066  0.393065   2.586928
# 2015-01-07  1.491022 -0.716088 -0.285711  -0.561717
# 2015-01-08  0.287355 -0.181889  0.392644  -0.967722
# 2015-01-09 -0.885235  0.626959 -0.589550   0.213824
# ...              ...       ...       ...        ...
# 2025-12-23  0.635800  0.855791  0.705548   3.727556
# 2025-12-24 -0.051405 -0.049082  0.410043   0.771645
# 2025-12-26 -2.797987  1.076628  4.759001   7.399134
# 2025-12-29  2.334194 -4.608798 -4.904599  -9.067170
# 2025-12-30 -0.224082  1.035063  4.225981  10.221479
#
# [2759 rows x 4 columns]

# %%
daily_cum_returns = (log_returns + 1).cumprod()
daily_cum_returns
# Out:
# Ticker          CL=F      GC=F      HG=F      SI=F
# Date
# 2015-01-05  0.948397  1.014980  0.983841  1.027890
# 2015-01-06  0.907539  1.027881  0.987708  1.054481
# 2015-01-07  0.921071  1.020521  0.984886  1.048558
# 2015-01-08  0.923717  1.018664  0.988753  1.038411
# 2015-01-09  0.915540  1.025051  0.982924  1.040631
# ...              ...       ...       ...       ...
# 2025-12-23  0.684211  3.370764  1.439585  2.871084
# 2025-12-24  0.683859  3.369110  1.445488  2.893238
# 2025-12-26  0.664725  3.405382  1.514279  3.107313
# 2025-12-29  0.680241  3.248435  1.440009  2.825568
# 2025-12-30  0.678717  3.282058  1.500864  3.114382
#
# [2759 rows x 4 columns]

# %%
daily_cum_returns.plot()
